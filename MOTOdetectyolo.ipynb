# %% [markdown]
# <a href="https://colab.research.google.com/github/5orachat/YOLO_Motodetect/blob/main/MOTOdetectyolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb#scrollTo=tdSMcABDNKW-
# !nvidia-smi
# Out:
# Sun Nov  5 14:46:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.52

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.52 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 97.7MB/s]
# 2023-11-05 14:47:16.735552: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-05 14:47:16.735613: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-05 14:47:16.735656: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-05 14:47:16.747645: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile
#แก้เป็นตำแหน่งไฟล์ใน drive ตนเอง waste.v3i.yolov8.zip คือ dataset จาก roboflow
local_zip = 'drive/MyDrive/AI/YOLO.v3i.yolov8.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('.')
zip_ref.close()

# %%
#ทดสอบดูรูปในชุดข้อมูล
# %cd {HOME}
#แก้เป็นชื่อไฟล์ของตนเอง 716886619_177245_mp4-10_jpg.rf.2362917a47e29a40d2d1f2627bad624f.jpg
Image(filename='train/images/scooters_-_5638-Original-_mp4-41_jpg.rf.338ddf02cda639d4fff2e5189d949c52.jpg', height=600)
# Out:
# /content

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=25 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.0.207 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.52 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#%cd {HOME}
#!yolo task=detect mode=train model=yolov5nu.pt data=data.yaml epochs=25 plots=True

# %%
#%cd {HOME}
#!yolo task=detect mode=train model=yolov5xu.pt data=data.yaml epochs=25 plots=True

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8x.pt data=data.yaml epochs=25 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.0.207 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.52 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#ใช้ตอบตาราง 1
# %cd {HOME}
# !yolo task=detect mode=val data=data.yaml model=./runs/detect/train/weights/best.pt device=0
# Out:
# /content
# 2023-11-05 16:20:52.923545: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-05 16:20:52.923598: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-05 16:20:52.923633: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-05 16:20:52.931389: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
#ใช้ตอบตาราง 2
# %cd {HOME}
# !yolo task=detect mode=val  data=data.yaml  model=./runs/detect/train2/weights/best.pt device=0
# Out:
# /content
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cfg/__init__.py", line 292, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 96, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 135, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 403, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 343, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
# ...

# %%
#ใช้เป็นสำหรับ รูป 1-2 8n
# %cd {HOME}
# !yolo task=detect mode=predict  data=data.yaml  source=test/images model=./runs/detect/train/weights/best.pt device=0 save=True
# Out:
# /content
# 2023-11-05 16:24:54.642893: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-05 16:24:54.642972: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-05 16:24:54.643018: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-05 16:24:54.651872: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
#ใช้เป็นสำหรับ รูป 1-2 8x
# %cd {HOME}
# !yolo task=detect mode=predict  data=data.yaml  source=test/images model=./runs/detect/train2/weights/best.pt device=0 save=True
# Out:
# /content
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cfg/__init__.py", line 292, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 96, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 135, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 403, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 343, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
# ...

# %%
#ใช้เป็นสร้าง vdo
#แก้ชื่อให้ตรงกับ vdo ของเรา vdo1.mp4 => dog.mp4
# %cd {HOME}
# !yolo task=detect mode=predict  data=data.yaml  source=drive/MyDrive/AI/vdo1.mp4 model=./runs/detect/train/weights/best.pt device=0 save=True
# Out:
# /content
# 2023-11-05 16:25:10.053388: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-05 16:25:10.053449: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-05 16:25:10.053486: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-05 16:25:10.060837: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
#ใช้เป็นสร้าง vdo
#แก้ชื่อให้ตรงกับ vdo ของเรา vdo1.mp4 => dog.mp4
# %cd {HOME}
# !yolo task=detect mode=predict  data=data.yaml  source=drive/MyDrive/AI/vdo13.mp4 model=./runs/detect/train/weights/best.pt device=0 save=True
# Out:
# /content
# 2023-11-05 16:25:36.683771: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-05 16:25:36.683825: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-05 16:25:36.683859: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-05 16:25:36.691540: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
#แสดงค่า confusion matrix
from ultralytics import YOLO
model_path = './runs/detect/train/weights/best.pt' # แก้ที่นี่
# Load a model
model = YOLO(model_path)  # load an official model

metrics = model.val()
yolo8n_conf = metrics.confusion_matrix.matrix
# Out:
# Ultralytics YOLOv8.0.52 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/valid/labels.cache... 116 images, 0 backgrounds, 0 corrupt: 100%|██████████| 116/116 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:06<00:00,  1.16it/s]
#                    all        116        343      0.761      0.598      0.749      0.425
#              motorbike        116          8      0.585        0.5      0.597      0.348
#             motorcycle        116        335      0.936      0.697      0.902      0.501
# Speed: 5.8ms preprocess, 8.2ms inference, 0.0ms loss, 7.7ms postprocess per image
# Results saved to runs/detect/val2

# %%
#zip และ copy ลงไปใน drive
# %cd {HOME}
# !zip -r /content/drive/MyDrive/AI/results.zip ./runs
# Out:
# /content
# updating: runs/ (stored 0%)
# updating: runs/detect/ (stored 0%)
# updating: runs/detect/predict2/ (stored 0%)
# updating: runs/detect/predict2/youtube-29_jpg.rf.60caa88a9a36ac7fe768701aabc6084a.jpg (deflated 4%)
# updating: runs/detect/predict2/youtube-35_jpg.rf.d569d9d964f5fbc4c19b3a47b0834343.jpg (deflated 4%)
# updating: runs/detect/predict2/youtube-103_jpg.rf.7d0ac39f9e8277e942db894e015201d1.jpg (deflated 4%)
# updating: runs/detect/predict2/youtube-99_jpg.rf.07806c978b8c0afce4eed5ce89bed082.jpg (deflated 4%)
# updating: runs/detect/predict2/youtube-29_jpg.rf.4870dd262517c5789a1353d935978bbc.jpg (deflated 5%)
# updating: runs/detect/predict2/youtube-36_jpg.rf.dfedc1a87d487e74ce6ffa75acd17ef5.jpg (deflated 4%)
# updating: runs/detect/predict2/youtube-210_jpg.rf.ecce23599c052185a47662fa9988e89a.jpg (deflated 4%)
# updating: runs/detect/predict2/youtube-105_jpg.rf.706b1727ac6228483bc1d9cd1451e9a2.jpg (deflated 4%)
# ...
